# %%
from dummy_lambda import execute

execute("1")
# Out:
# [{'code': '1',
#   'type': 'https://spn.geoprism.net#FloodScenario',
#   'uri': 'https://spn.geoprism.net#FloodScenario-1'},
#  {'code': '1',
#   'type': 'https://spn.geoprism.net#ProjectArea',
#   'uri': 'https://spn.geoprism.net#ProjectArea-1'},
#  {'code': '1',
#   'type': 'https://spn.geoprism.net#FloodScenario',
#   'uri': 'https://spn.geoprism.net#FloodScenario-1'}]
