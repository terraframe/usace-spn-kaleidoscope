# %%
from dummy_lambda import execute

sparql = """
  PREFIX lpg: <https://spn.geoprism.net#> 
  PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> 
  PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#> 
  
  SELECT ?scenario ?label 
  FROM <https://spn.geoprism.net/spn>   
  WHERE {   
    # ?scenario rdf:type lpg:FloodScenario .   
    # ?scenario rdfs:label ?label . 
  }
  LIMIT 100
"""

execute(sparql)
# Out:
# 'https://spn.geoprism.net#FloodScenario-1,1\n'
